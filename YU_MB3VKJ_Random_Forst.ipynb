# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import metrics


from sklearn.ensemble import RandomForestClassifier
from sklearn.mixture import GaussianMixture

# %%
def remove_NaN(df, t):
    return df.dropna(axis=1, thresh=int(((100-t)/100)*df.shape[0] + 1))

# %%
def scale(X_train, X_val, X_test):
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
    X_val = pd.DataFrame(scaler.transform(X_val), columns=X_val.columns)
    X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)
    return X_train, X_val, X_test

# %%
def impute(X_train, X_val, X_test):
    imputer = SimpleImputer(strategy = 'most_frequent')
    imputer.fit(X_train)
    X_train = pd.DataFrame(imputer.transform(X_train), columns=X_train.columns)
    X_val = pd.DataFrame(imputer.transform(X_val), columns=X_val.columns)
    X_test = pd.DataFrame(imputer.transform(X_test), columns=X_test.columns)
    return X_train, X_val, X_test

# %%
sm = SMOTE(random_state=42)
def over_sampling(X, Y): 
    x, y = sm.fit_resample(X, Y)
    return x,y

# %%
def score_calc(model, y_val,  y_pred):
    print(model)
    print("Confusion Matrix")
    print(metrics.confusion_matrix(y_val, y_pred))
    print(f"Validation F3 Score: {metrics.fbeta_score(y_val, y_pred, beta=3)}")
    print(f"Classification Report\n{metrics.classification_report(y_val, y_pred)}")

# %%
def save_model(model, test_pred, name, best_estimator=False):
    if best_estimator:
        print(f"Best Estimator: {model.best_estimator_}")
    dataset = pd.DataFrame({'Id':  np.arange(test_pred.size), 'Predicted':test_pred}, columns=['Id', 'Predicted'])
    dataset.to_csv(f"{name}_MB3VKJ.csv", index=False)

# %%
X = pd.read_csv('data/X_train.csv')
X.drop(["Id"], axis=1, inplace=True)
y = pd.read_csv('data/Y_train.csv')
y.drop(["Id"], axis=1, inplace=True)
X_test = pd.read_csv('data/X_test.csv')
X_test.drop(["Id"], axis=1, inplace=True)
X_train, X_val, y_train, y_val = train_test_split(X, y, stratify=y, test_size=0.25)


# 20, 30, 40, 60
X_train_20 = remove_NaN(X_train, 20)
X_val_20 = X_val[X_train_20.columns.tolist()]
X_test_20 = X_test[X_train_20.columns.tolist()]
X_train_20, X_val_20, X_test_20 = scale(X_train_20, X_val_20, X_test_20)
X_train_20, X_val_20, X_test_20 = impute(X_train_20, X_val_20, X_test_20)

X_train_30 = remove_NaN(X_train, 30)
X_val_30 = X_val[X_train_30.columns.tolist()]
X_test_30 = X_test[X_train_30.columns.tolist()]
X_train_30, X_val_30, X_test_30 = scale(X_train_30, X_val_30, X_test_30)
X_train_30, X_val_30, X_test_30 = impute(X_train_30, X_val_30, X_test_30)

X_train_40 = remove_NaN(X_train, 40)
X_val_40 = X_val[X_train_40.columns.tolist()]
X_test_40 = X_test[X_train_40.columns.tolist()]
X_train_40, X_val_40, X_test_40 = scale(X_train_40, X_val_40, X_test_40)
X_train_40, X_val_40, X_test_40 = impute(X_train_40, X_val_40, X_test_40)

X_train_60 = remove_NaN(X_train, 60)
X_val_60 = X_val[X_train_60.columns.tolist()]
X_test_60 = X_test[X_train_60.columns.tolist()]
X_train_60, X_val_60, X_test_60 = scale(X_train_60, X_val_60, X_test_60)
X_train_60, X_val_60, X_test_60 = impute(X_train_60, X_val_60, X_test_60)


# # 0.99 0.95
pca_95 = PCA(0.95)
X_train_20_95 = pca_95.fit(X_train_20).transform(X_train_20)
X_val_20_95 = pca_95.transform(X_val_20)
X_test_20_95 = pca_95.transform(X_test_20)

pca_95 = PCA(0.95)
X_train_30_95 = pca_95.fit(X_train_30).transform(X_train_30)
X_val_30_95 = pca_95.transform(X_val_30)
X_test_30_95 = pca_95.transform(X_test_30)

pca_95 = PCA(0.95)
X_train_40_95 = pca_95.fit(X_train_40).transform(X_train_40)
X_val_40_95 = pca_95.transform(X_val_40)
X_test_40_95 = pca_95.transform(X_test_40)

pca_95 = PCA(0.95)
X_train_60_95 = pca_95.fit(X_train_60).transform(X_train_60)
X_val_60_95 = pca_95.transform(X_val_60)
X_test_60_95 = pca_95.transform(X_test_60)

pca_99 = PCA(0.99)
X_train_20_99 = pca_99.fit(X_train_20).transform(X_train_20)
X_val_20_99 = pca_99.transform(X_val_20)
X_test_20_99 = pca_99.transform(X_test_20)

pca_99 = PCA(0.99)
X_train_30_99 = pca_99.fit(X_train_30).transform(X_train_30)
X_val_30_99 = pca_99.transform(X_val_30)
X_test_30_99 = pca_99.transform(X_test_30)

pca_99 = PCA(0.99)
X_train_40_99 = pca_99.fit(X_train_40).transform(X_train_40)
X_val_40_99 = pca_99.transform(X_val_40)
X_test_40_99 = pca_99.transform(X_test_40)

pca_99 = PCA(0.99)
X_train_60_99 = pca_99.fit(X_train_60).transform(X_train_60)
X_val_60_99 = pca_99.transform(X_val_60)
X_test_60_99 = pca_99.transform(X_test_60)

# %%
X, y = over_sampling(X_train_20_95, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_20_95)
test_pred = gridSearch.predict(X_test_20_95)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.981 total time=  43.4s
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  43.5s
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.983 total time=  43.4s
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  43.5s
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.981 total time=  43.6s
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time=  51.7s
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.983 total time=  51.7s
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.981 total time=  51.7s
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.987 total time=  51.8s
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.981 total time=  51.9s
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.987 total time= 1.0min
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.980 total time= 1.0min
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.982 total time= 1.0min
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.987 total time= 1.0min
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.980 total time= 1.0min
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.2min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.2min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.981 total time= 1.2min
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.981 total time= 1.2min
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.983 total time= 1.2min
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time=  59.5s
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.0min
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.997 total time= 1.0min
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.0min
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.997 total time= 1.0min
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.2min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.2min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.997 total time= 1.2min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.997 total time= 1.3min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.4min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.997 total time= 1.4min
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.997 total time= 1.4min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.7min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.997 total time= 1.7min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.997 total time= 1.7min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.0min
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.0min
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.0min
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.0min
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.3min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.3min
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.3min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.7min
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.7min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.7min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.992 total time=  54.1s
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.990 total time=  53.9s
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  53.8s
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.991 total time=  54.2s
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  54.1s
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.992 total time= 1.0min
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.991 total time= 1.0min
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.989 total time= 1.0min
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.991 total time= 1.0min
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time= 1.0min
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.992 total time= 1.2min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.991 total time= 1.2min
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time= 1.2min
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.990 total time= 1.2min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time= 1.2min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.992 total time= 1.4min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.991 total time= 1.4min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.991 total time= 1.4min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.4min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.4min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  57.2s
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  58.5s
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  58.0s
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time=  58.2s
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time=  58.4s
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.2min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.2min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.4min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.4min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.6min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.6min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.6min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.6min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  57.3s
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  58.5s
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  58.1s
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time=  58.6s
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time=  58.3s
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.2min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.2min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.4min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.4min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.6min
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.6min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.6min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.6min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.6min

# %%
# X_train_20_95
score_calc("Random Forest NAN 20 PCA 95%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_20_95", True)
# Out:
# Random Forest NAN 20 PCA 95%
# Confusion Matrix
# [[9683  112]
#  [  24  156]]
# Validation F3 Score: 0.8262711864406782
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9795
#            1       0.58      0.87      0.70       180
#
#     accuracy                           0.99      9975
#    macro avg       0.79      0.93      0.84      9975
# weighted avg       0.99      0.99      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=30, max_features='sqrt',
#                        n_estimators=150, random_state=42)

# %%
X, y = over_sampling(X_train_20_95, y_train)
y_train_ravel = y.values.ravel()

params = [{"n_components": [2],
          "covariance_type": ["spherical", "tied", "diag", "full"]}]
model = GaussianMixture(random_state=42)
CgridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
CgridSearch.fit(X, y_train_ravel)
y_pred_val = CgridSearch.predict(X_train_20_95)
test_pred = CgridSearch.predict(X_test_20_95)

train_pred = CgridSearch.predict(X_train_20_95)
pred = np.reshape(train_pred, (train_pred.shape[0], 1))
X_train_20_95_cluster = np.append(X_train_20_95, pred, axis=1)

y_pred_val = CgridSearch.predict(X_val_20_95)
pred = np.reshape(y_pred_val, (y_pred_val.shape[0], 1))
X_val_20_95_cluster = np.append(X_val_20_95, pred, axis=1)

test_pred = CgridSearch.predict(X_test_20_95)
pred = np.reshape(test_pred, (test_pred.shape[0], 1))
X_test_20_95_cluster = np.append(X_test_20_95, pred, axis=1)

print(X_train_20_95_cluster[0].size)
print(X_val_20_95_cluster[0].size)
print(X_test_20_95_cluster[0].size)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 3/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 1/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 2/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 5/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 5/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.964 total time=   0.9s
# [CV 4/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.962 total time=   0.9s
# [CV 2/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 1/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 3/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.959 total time=   1.0s
# [CV 3/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 1/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.977 total time=   1.1s
# [CV 2/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.965 total time=   1.2s
# [CV 4/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 5/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 5/5; 2/4] END covariance_type=tied, n_components=2;, score=0.440 total time=   3.4s
# [CV 1/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 1/5; 3/4] END covariance_type=diag, n_components=2;, score=0.982 total time=   2.2s
# [CV 2/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 1/5; 2/4] END covariance_type=tied, n_components=2;, score=0.332 total time=   7.8s
# [CV 3/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 2/5; 2/4] END covariance_type=tied, n_components=2;, score=0.342 total time=   8.1s
# [CV 4/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 2/5; 3/4] END covariance_type=diag, n_components=2;, score=0.980 total time=   2.3s
# [CV 5/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 4/5; 2/4] END covariance_type=tied, n_components=2;, score=0.347 total time=   8.3s
# [CV 1/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 3/5; 2/4] END covariance_type=tied, n_components=2;, score=0.327 total time=   8.9s
# [CV 2/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 3/5; 3/4] END covariance_type=diag, n_components=2;, score=0.972 total time=   1.5s
# [CV 4/5; 3/4] END covariance_type=diag, n_components=2;, score=0.975 total time=   1.2s
# [CV 3/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 4/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 5/5; 3/4] END covariance_type=diag, n_components=2;, score=0.974 total time=   1.3s
# [CV 5/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 3/5; 4/4] END covariance_type=full, n_components=2;, score=0.871 total time=   6.1s
# [CV 2/5; 4/4] END covariance_type=full, n_components=2;, score=0.844 total time=   8.1s
# [CV 4/5; 4/4] END covariance_type=full, n_components=2;, score=0.982 total time=   8.6s
# [CV 5/5; 4/4] END covariance_type=full, n_components=2;, score=0.982 total time=   8.4s
# [CV 1/5; 4/4] END covariance_type=full, n_components=2;, score=0.877 total time=   9.9s
# 70
# 70
# 70

# %%
X, y = over_sampling(X_train_20_95_cluster, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_20_95_cluster)
test_pred = gridSearch.predict(X_test_20_95_cluster)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.990 total time=  47.5s
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  47.5s
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time=  47.6s
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time=  47.7s
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time=  47.8s
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.989 total time=  59.0s
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.989 total time=  59.2s
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time=  59.1s
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.990 total time=  59.2s
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.989 total time=  59.4s
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time= 1.1min
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time= 1.1min
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.990 total time= 1.1min
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time= 1.1min
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time= 1.1min
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.5min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.5min
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.5min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.5min
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.990 total time= 1.5min
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.4s
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.9s
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  55.2s
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time=  55.3s
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time=  55.5s
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.1min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.1min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.3min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.3min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.5min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  52.6s
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.1s
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.0s
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time=  54.8s
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time=  54.7s
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.1min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.1min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.3min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.3min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.5min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.5min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.990 total time=  49.7s
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.990 total time=  49.8s
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.991 total time=  50.3s
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.991 total time=  50.3s
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.990 total time=  49.6s
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.991 total time= 1.0min
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.990 total time= 1.0min
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.991 total time= 1.0min
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.991 total time= 1.0min
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.991 total time= 1.0min
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.991 total time= 1.2min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.990 total time= 1.2min
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.991 total time= 1.2min
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.991 total time= 1.2min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.991 total time= 1.2min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.990 total time= 1.3min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.990 total time= 1.3min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.991 total time= 1.3min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.991 total time= 1.3min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.991 total time= 1.3min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  53.5s
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.6s
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.0s
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  53.8s
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.6s
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  53.4s
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  53.5s
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.3s
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.4s
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  53.8s
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.2min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min

# %%
score_calc("Random Forest With Cluster NAN 20 PCA 95%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_Cluster_20_95", True)
# Out:
# Random Forest With Cluster NAN 20 PCA 95%
# Confusion Matrix
# [[9673  121]
#  [  22  159]]
# Validation F3 Score: 0.8328968046097434
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9794
#            1       0.57      0.88      0.69       181
#
#     accuracy                           0.99      9975
#    macro avg       0.78      0.93      0.84      9975
# weighted avg       0.99      0.99      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=20, max_features='sqrt',
#                        n_estimators=200, random_state=42)

# %%
X, y = over_sampling(X_train_30_95, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_30_95)
test_pred = gridSearch.predict(X_test_30_95)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.981 total time=  45.7s
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.980 total time=  45.7s
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.981 total time=  45.7s
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.978 total time=  45.8s
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.980 total time=  45.7s
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.981 total time=  52.8s
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.980 total time=  52.9s
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.981 total time=  52.9s
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.981 total time=  52.9s
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.978 total time=  53.0s
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.981 total time= 1.0min
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.980 total time= 1.0min
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.978 total time= 1.0min
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.981 total time= 1.0min
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.980 total time= 1.0min
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.980 total time= 1.2min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.981 total time= 1.2min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.980 total time= 1.2min
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.981 total time= 1.2min
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.977 total time= 1.2min
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.1min
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.997 total time= 1.1min
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.996 total time= 1.1min
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.997 total time= 1.1min
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.2min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.996 total time= 1.2min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.997 total time= 1.2min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.997 total time= 1.2min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.996 total time= 1.4min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.997 total time= 1.4min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.997 total time= 1.4min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.6min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.996 total time= 1.6min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.997 total time= 1.6min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.997 total time= 1.6min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.6min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.997 total time= 1.0min
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.0min
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.997 total time= 1.0min
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.0min
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.0min
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.997 total time= 1.2min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.997 total time= 1.2min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.2min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.997 total time= 1.4min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.997 total time= 1.4min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.4min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.997 total time= 1.6min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.997 total time= 1.6min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.6min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.6min
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.6min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.983 total time=  53.3s
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.982 total time=  53.1s
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.981 total time=  53.2s
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.983 total time=  53.5s
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.984 total time=  53.6s
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.983 total time= 1.1min
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.982 total time= 1.1min
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.983 total time= 1.1min
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.981 total time= 1.1min
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.984 total time= 1.1min
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.983 total time= 1.2min
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.981 total time= 1.2min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.983 total time= 1.2min
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.981 total time= 1.2min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.983 total time= 1.2min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.983 total time= 1.5min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.983 total time= 1.5min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.981 total time= 1.5min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.981 total time= 1.5min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.983 total time= 1.5min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time=  58.9s
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  59.6s
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  59.3s
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time=  59.9s
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time=  59.6s
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.3min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.3min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.3min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.8min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.8min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.8min
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.8min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.0min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.0min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.0min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.2min
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.2min
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.2min
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.5min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.5min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.5min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.5min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.5min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.7min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.7min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.7min

# %%
score_calc("Random Forest NAN 30 PCA 95%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_30_95", True)
# Out:
# Random Forest NAN 30 PCA 95%
# Confusion Matrix
# [[9677  118]
#  [  29  151]]
# Validation F3 Score: 0.7993647432503972
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9795
#            1       0.56      0.84      0.67       180
#
#     accuracy                           0.99      9975
#    macro avg       0.78      0.91      0.83      9975
# weighted avg       0.99      0.99      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=20, max_features='sqrt',
#                        n_estimators=175, random_state=42)

# %%
X, y = over_sampling(X_train_30_95, y_train)
y_train_ravel = y.values.ravel()

params = [{"n_components": [2],
          "covariance_type": ["spherical", "tied", "diag", "full"]}]
model = GaussianMixture(random_state=42)
CgridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
CgridSearch.fit(X, y_train_ravel)
y_pred_val = CgridSearch.predict(X_train_30_95)
test_pred = CgridSearch.predict(X_test_30_95)

train_pred = CgridSearch.predict(X_train_30_95)
pred = np.reshape(train_pred, (train_pred.shape[0], 1))
X_train_30_95_cluster = np.append(X_train_30_95, pred, axis=1)

y_pred_val = CgridSearch.predict(X_val_30_95)
pred = np.reshape(y_pred_val, (y_pred_val.shape[0], 1))
X_val_30_95_cluster = np.append(X_val_30_95, pred, axis=1)

test_pred = CgridSearch.predict(X_test_30_95)
pred = np.reshape(test_pred, (test_pred.shape[0], 1))
X_test_30_95_cluster = np.append(X_test_30_95, pred, axis=1)

print(X_train_30_95_cluster[0].size)
print(X_val_30_95_cluster[0].size)
print(X_test_30_95_cluster[0].size)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 2/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 1/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 3/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 5/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.960 total time=   1.1s
# [CV 5/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.964 total time=   1.1s
# [CV 1/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 2/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 3/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.957 total time=   1.2s
# [CV 3/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 1/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.973 total time=   1.4s
# [CV 2/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.965 total time=   1.4s
# [CV 4/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 5/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 1/5; 2/4] END covariance_type=tied, n_components=2;, score=0.373 total time=   5.5s
# [CV 1/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 2/5; 2/4] END covariance_type=tied, n_components=2;, score=0.432 total time=   5.6s
# [CV 2/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 3/5; 2/4] END covariance_type=tied, n_components=2;, score=0.385 total time=   6.6s
# [CV 3/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 5/5; 2/4] END covariance_type=tied, n_components=2;, score=0.385 total time=   6.4s
# [CV 4/5; 2/4] END covariance_type=tied, n_components=2;, score=0.386 total time=   6.4s
# [CV 4/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 5/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 2/5; 3/4] END covariance_type=diag, n_components=2;, score=0.980 total time=   2.5s
# [CV 1/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 1/5; 3/4] END covariance_type=diag, n_components=2;, score=0.977 total time=   2.6s
# [CV 2/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 5/5; 3/4] END covariance_type=diag, n_components=2;, score=0.969 total time=   1.5s
# [CV 4/5; 3/4] END covariance_type=diag, n_components=2;, score=0.968 total time=   1.5s
# [CV 3/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 4/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 3/5; 3/4] END covariance_type=diag, n_components=2;, score=0.961 total time=   1.8s
# [CV 5/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 2/5; 4/4] END covariance_type=full, n_components=2;, score=0.859 total time=   7.1s
# [CV 3/5; 4/4] END covariance_type=full, n_components=2;, score=0.869 total time=   8.0s
# [CV 1/5; 4/4] END covariance_type=full, n_components=2;, score=0.895 total time=  10.6s
# [CV 5/5; 4/4] END covariance_type=full, n_components=2;, score=0.977 total time=  10.3s
# [CV 4/5; 4/4] END covariance_type=full, n_components=2;, score=0.983 total time=  10.5s
# 77
# 77
# 77

# %%
X, y = over_sampling(X_train_30_95_cluster, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_30_95_cluster)
test_pred = gridSearch.predict(X_test_30_95_cluster)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.985 total time=  46.1s
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.984 total time=  46.4s
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.985 total time=  46.4s
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.985 total time=  46.5s
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.985 total time=  46.5s
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.984 total time=  49.1s
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.986 total time=  49.4s
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.986 total time=  49.5s
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.983 total time=  49.5s
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.985 total time=  49.8s
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.985 total time=  57.4s
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.986 total time=  57.9s
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.986 total time=  57.8s
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.984 total time=  57.8s
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.985 total time=  58.1s
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.985 total time= 1.1min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.985 total time= 1.1min
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.986 total time= 1.1min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.986 total time= 1.1min
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.985 total time= 1.1min
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.997 total time=  57.4s
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  56.5s
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time=  56.9s
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time=  57.2s
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time=  58.5s
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.997 total time= 1.1min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.1min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.1min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.1min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.2min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.3min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.997 total time= 1.3min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.3min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.3min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.5min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.5min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.5min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.5min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  57.2s
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  57.9s
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time=  58.7s
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time=  58.5s
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  58.4s
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.1min
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.1min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.4min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.4min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.4min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.4min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.6min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.6min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.6min
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.6min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.984 total time=  51.2s
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.986 total time=  51.7s
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  51.4s
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  51.2s
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.984 total time=  51.3s
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.984 total time=  58.8s
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time=  58.7s
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.987 total time=  59.1s
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time=  58.9s
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.984 total time=  59.2s
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.984 total time= 1.1min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.986 total time= 1.1min
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time= 1.1min
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time= 1.1min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.985 total time= 1.1min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.985 total time= 1.3min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.3min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.987 total time= 1.3min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.3min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.985 total time= 1.3min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  53.1s
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  52.7s
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time=  53.9s
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.6s
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  53.8s
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.0min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.1min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.2min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.2min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.3min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  52.8s
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  53.1s
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time=  54.1s
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.0s
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.8s
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.2min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.2min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.3min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min

# %%
score_calc("Random Forest With Cluster NAN 30 PCA 95%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_Cluster_30_95", True)
# Out:
# Random Forest With Cluster NAN 30 PCA 95%
# Confusion Matrix
# [[9665  129]
#  [  22  159]]
# Validation F3 Score: 0.8294209702660408
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9794
#            1       0.55      0.88      0.68       181
#
#     accuracy                           0.98      9975
#    macro avg       0.77      0.93      0.84      9975
# weighted avg       0.99      0.98      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=30, max_features='sqrt',
#                        n_estimators=150, random_state=42)

# %%
X, y = over_sampling(X_train_40_95, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_40_95)
test_pred = gridSearch.predict(X_test_40_95)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.983 total time=  56.6s
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.982 total time=  56.6s
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.978 total time=  56.7s
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.981 total time=  56.7s
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.981 total time=  56.8s
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.983 total time= 1.2min
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.982 total time= 1.2min
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.981 total time= 1.1min
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.978 total time= 1.2min
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.981 total time= 1.2min
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.982 total time= 1.5min
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.983 total time= 1.5min
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.981 total time= 1.5min
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.978 total time= 1.5min
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.982 total time= 1.5min
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.983 total time= 1.6min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.983 total time= 1.6min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.982 total time= 1.6min
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.979 total time= 1.6min
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.982 total time= 1.6min
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.4min
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.4min
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.4min
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.4min
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.4min
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.7min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.7min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.7min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.7min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.7min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 2.1min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 2.1min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.1min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 2.1min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 2.1min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.9min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.9min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.997 total time= 1.9min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.9min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.3min
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.3min
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.3min
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.5min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.6min
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.6min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.6min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.8min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.9min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.9min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.9min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.0min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.1min
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.1min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.983 total time= 1.1min
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.985 total time= 1.2min
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.985 total time= 1.2min
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.980 total time= 1.2min
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.986 total time= 1.2min
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.983 total time= 1.3min
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.985 total time= 1.4min
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.985 total time= 1.3min
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.980 total time= 1.3min
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.986 total time= 1.3min
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.983 total time= 1.6min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.986 total time= 1.6min
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.985 total time= 1.6min
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.981 total time= 1.6min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.986 total time= 1.6min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.983 total time= 1.8min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.986 total time= 1.8min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.985 total time= 1.8min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.980 total time= 1.8min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.986 total time= 1.8min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.2min
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.5min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.7min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.7min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.9min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.0min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.9min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min

# %%
score_calc("Random Forest NAN 40 PCA 95%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_40_95", True)
# Out:
# Random Forest NAN 40 PCA 95%
# Confusion Matrix
# [[9688  107]
#  [  26  154]]
# Validation F3 Score: 0.8187134502923978
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9795
#            1       0.59      0.86      0.70       180
#
#     accuracy                           0.99      9975
#    macro avg       0.79      0.92      0.85      9975
# weighted avg       0.99      0.99      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=20, max_features='sqrt',
#                        n_estimators=125, random_state=42)

# %%
X, y = over_sampling(X_train_40_95, y_train)
y_train_ravel = y.values.ravel()

params = [{"n_components": [2],
          "covariance_type": ["spherical", "tied", "diag", "full"]}]
model = GaussianMixture(random_state=42)
CgridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
CgridSearch.fit(X, y_train_ravel)
y_pred_val = CgridSearch.predict(X_train_40_95)
test_pred = CgridSearch.predict(X_test_40_95)

train_pred = CgridSearch.predict(X_train_40_95)
pred = np.reshape(train_pred, (train_pred.shape[0], 1))
X_train_40_95_cluster = np.append(X_train_40_95, pred, axis=1)

y_pred_val = CgridSearch.predict(X_val_40_95)
pred = np.reshape(y_pred_val, (y_pred_val.shape[0], 1))
X_val_40_95_cluster = np.append(X_val_40_95, pred, axis=1)

test_pred = CgridSearch.predict(X_test_40_95)
pred = np.reshape(test_pred, (test_pred.shape[0], 1))
X_test_40_95_cluster = np.append(X_test_40_95, pred, axis=1)

print(X_train_40_95_cluster[0].size)
print(X_val_40_95_cluster[0].size)
print(X_test_40_95_cluster[0].size)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 3/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 2/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 5/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.947 total time=   0.9s
# [CV 1/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 5/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.951 total time=   1.0s
# [CV 2/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 3/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.940 total time=   1.1s
# [CV 3/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 1/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.955 total time=   1.3s
# [CV 4/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 2/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.960 total time=   1.4s
# [CV 5/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 2/5; 2/4] END covariance_type=tied, n_components=2;, score=0.457 total time=   5.0s
# [CV 1/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 1/5; 2/4] END covariance_type=tied, n_components=2;, score=0.382 total time=   5.6s
# [CV 2/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 4/5; 2/4] END covariance_type=tied, n_components=2;, score=0.394 total time=   5.9s
# [CV 3/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 3/5; 2/4] END covariance_type=tied, n_components=2;, score=0.386 total time=   7.0s
# [CV 4/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 5/5; 2/4] END covariance_type=tied, n_components=2;, score=0.383 total time=   7.2s
# [CV 5/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 1/5; 3/4] END covariance_type=diag, n_components=2;, score=0.977 total time=   2.9s
# [CV 1/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 3/5; 3/4] END covariance_type=diag, n_components=2;, score=0.957 total time=   1.9s
# [CV 2/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 2/5; 3/4] END covariance_type=diag, n_components=2;, score=0.975 total time=   2.8s
# [CV 3/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 4/5; 3/4] END covariance_type=diag, n_components=2;, score=0.967 total time=   1.5s
# [CV 4/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 5/5; 3/4] END covariance_type=diag, n_components=2;, score=0.967 total time=   1.4s
# [CV 5/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 2/5; 4/4] END covariance_type=full, n_components=2;, score=0.854 total time=   6.9s
# [CV 3/5; 4/4] END covariance_type=full, n_components=2;, score=0.870 total time=   7.7s
# [CV 1/5; 4/4] END covariance_type=full, n_components=2;, score=0.886 total time=  10.0s
# [CV 5/5; 4/4] END covariance_type=full, n_components=2;, score=0.983 total time=   9.3s
# [CV 4/5; 4/4] END covariance_type=full, n_components=2;, score=0.985 total time=   9.9s
# 77
# 77
# 77

# %%
X, y = over_sampling(X_train_40_95_cluster, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_40_95_cluster)
test_pred = gridSearch.predict(X_test_40_95_cluster)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.986 total time=  46.1s
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  46.3s
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.982 total time=  46.4s
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.987 total time=  46.4s
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.984 total time=  46.6s
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.986 total time=  52.3s
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.983 total time=  52.8s
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time=  52.8s
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.987 total time=  52.8s
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.985 total time=  53.0s
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.986 total time= 1.1min
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.983 total time= 1.1min
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time= 1.1min
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.987 total time= 1.1min
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.985 total time= 1.1min
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.987 total time= 1.2min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.983 total time= 1.2min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.2min
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.2min
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.985 total time= 1.2min
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.5s
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  55.1s
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  55.6s
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  56.0s
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  56.0s
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  55.5s
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  56.7s
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.2s
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  56.1s
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  55.6s
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  49.5s
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time=  49.7s
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  49.7s
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time=  49.7s
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.986 total time=  50.2s
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time=  59.0s
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.989 total time=  59.1s
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.990 total time=  59.0s
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.989 total time=  58.9s
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.986 total time=  59.6s
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time= 1.1min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.990 total time= 1.1min
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time= 1.1min
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time= 1.1min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.986 total time= 1.2min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.3min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.990 total time= 1.3min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.3min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.990 total time= 1.3min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.987 total time= 1.3min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.1s
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  53.8s
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.1s
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.8s
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time=  53.6s
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.3min
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.4s
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.5s
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.1s
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time=  53.7s
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  55.1s
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.2min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min

# %%
score_calc("Random Forest With Cluster NAN 40 PCA 95%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_Cluster_40_95", True)
# Out:
# Random Forest With Cluster NAN 40 PCA 95%
# Confusion Matrix
# [[9671  123]
#  [  21  160]]
# Validation F3 Score: 0.8368200836820083
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9794
#            1       0.57      0.88      0.69       181
#
#     accuracy                           0.99      9975
#    macro avg       0.78      0.94      0.84      9975
# weighted avg       0.99      0.99      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=20, max_features='sqrt',
#                        n_estimators=150, random_state=42)

# %%
X, y = over_sampling(X_train_60_95, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_60_95)
test_pred = gridSearch.predict(X_test_60_95)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.985 total time= 1.0min
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.982 total time= 1.0min
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.980 total time= 1.0min
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.982 total time= 1.0min
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.979 total time= 1.0min
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.982 total time= 1.1min
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.984 total time= 1.1min
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.981 total time= 1.1min
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.982 total time= 1.1min
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.979 total time= 1.1min
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.982 total time= 1.6min
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.985 total time= 1.6min
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.983 total time= 1.6min
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.979 total time= 1.6min
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.982 total time= 1.6min
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.982 total time= 1.9min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.984 total time= 1.9min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.979 total time= 1.9min
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.982 total time= 1.9min
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.983 total time= 1.9min
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.6min
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.997 total time= 1.6min
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.6min
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.6min
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.997 total time= 1.6min
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 2.1min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.997 total time= 2.1min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 2.1min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 2.1min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.997 total time= 2.1min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.1min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.1min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.1min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.1min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.997 total time= 2.1min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.3min
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.3min
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.6min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.7min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.7min
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.7min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.7min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.9min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.9min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.9min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.9min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.9min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.2min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.2min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.2min
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.2min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.985 total time= 1.2min
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time= 1.2min
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.981 total time= 1.2min
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.985 total time= 1.2min
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.985 total time= 1.2min
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.986 total time= 1.4min
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.989 total time= 1.4min
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.985 total time= 1.4min
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.981 total time= 1.4min
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.985 total time= 1.4min
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.984 total time= 1.6min
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time= 1.6min
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.985 total time= 1.6min
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.981 total time= 1.6min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.985 total time= 1.6min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.8min
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.984 total time= 1.8min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.985 total time= 1.8min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.981 total time= 1.8min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.985 total time= 1.8min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.1min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.1min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.6min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min

# %%
score_calc("Random Forest NAN 60 PCA 95%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_60_95", True)
# Out:
# Random Forest NAN 60 PCA 95%
# Confusion Matrix
# [[9680  115]
#  [  28  152]]
# Validation F3 Score: 0.8055113937466879
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9795
#            1       0.57      0.84      0.68       180
#
#     accuracy                           0.99      9975
#    macro avg       0.78      0.92      0.84      9975
# weighted avg       0.99      0.99      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=30, max_features='sqrt',
#                        n_estimators=150, random_state=42)

# %%
X, y = over_sampling(X_train_60_95, y_train)
y_train_ravel = y.values.ravel()

params = [{"n_components": [2],
          "covariance_type": ["spherical", "tied", "diag", "full"]}]
model = GaussianMixture(random_state=42)
CgridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
CgridSearch.fit(X, y_train_ravel)
y_pred_val = CgridSearch.predict(X_train_60_95)
test_pred = CgridSearch.predict(X_test_60_95)

train_pred = CgridSearch.predict(X_train_60_95)
pred = np.reshape(train_pred, (train_pred.shape[0], 1))
X_train_60_95_cluster = np.append(X_train_60_95, pred, axis=1)

y_pred_val = CgridSearch.predict(X_val_60_95)
pred = np.reshape(y_pred_val, (y_pred_val.shape[0], 1))
X_val_60_95_cluster = np.append(X_val_60_95, pred, axis=1)

test_pred = CgridSearch.predict(X_test_60_95)
pred = np.reshape(test_pred, (test_pred.shape[0], 1))
X_test_60_95_cluster = np.append(X_test_60_95, pred, axis=1)

print(X_train_60_95_cluster[0].size)
print(X_val_60_95_cluster[0].size)
print(X_test_60_95_cluster[0].size)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 2/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 3/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 5/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.938 total time=   1.1s[CV 5/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.942 total time=   1.1s
#
# [CV 2/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 1/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 3/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.070 total time=   1.1s
# [CV 3/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 1/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.932 total time=   1.3s[CV 2/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.955 total time=   1.3s
#
# [CV 4/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 5/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 2/5; 2/4] END covariance_type=tied, n_components=2;, score=0.417 total time=   5.7s
# [CV 1/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 3/5; 2/4] END covariance_type=tied, n_components=2;, score=0.592 total time=   5.9s
# [CV 2/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 1/5; 2/4] END covariance_type=tied, n_components=2;, score=0.364 total time=   6.5s
# [CV 3/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 4/5; 2/4] END covariance_type=tied, n_components=2;, score=0.384 total time=   6.4s
# [CV 4/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 5/5; 2/4] END covariance_type=tied, n_components=2;, score=0.378 total time=   6.8s
# [CV 5/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 4/5; 3/4] END covariance_type=diag, n_components=2;, score=0.968 total time=   1.4s
# [CV 1/5; 3/4] END covariance_type=diag, n_components=2;, score=0.977 total time=   2.5s
# [CV 1/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 2/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 3/5; 3/4] END covariance_type=diag, n_components=2;, score=0.040 total time=   1.7s
# [CV 3/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 2/5; 3/4] END covariance_type=diag, n_components=2;, score=0.980 total time=   2.5s
# [CV 5/5; 3/4] END covariance_type=diag, n_components=2;, score=0.969 total time=   1.4s
# [CV 4/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 5/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 3/5; 4/4] END covariance_type=full, n_components=2;, score=0.132 total time=   7.6s
# [CV 1/5; 4/4] END covariance_type=full, n_components=2;, score=0.891 total time=  10.1s
# [CV 5/5; 4/4] END covariance_type=full, n_components=2;, score=0.979 total time=   9.8s
# [CV 4/5; 4/4] END covariance_type=full, n_components=2;, score=0.984 total time=   9.9s
# [CV 2/5; 4/4] END covariance_type=full, n_components=2;, score=0.864 total time=  10.2s
# 78
# 78
# 78

# %%
X, y = over_sampling(X_train_60_95_cluster, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_60_95_cluster)
test_pred = gridSearch.predict(X_test_60_95_cluster)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  42.0s
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time=  42.1s
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  42.1s
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.986 total time=  42.2s
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.987 total time=  42.7s
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.989 total time=  49.8s
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.987 total time=  49.9s
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.989 total time=  49.8s
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time=  49.9s
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time=  50.6s
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time=  58.1s
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.987 total time=  58.3s
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time=  58.3s
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time=  58.3s
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time=  58.9s
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.987 total time= 1.1min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.1min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.1min
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.1min
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.1min
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  53.8s
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.2s
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.3s
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  55.4s
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time=  55.9s
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.2min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.3min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.3min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.5min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.5min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.5min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  54.0s
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time=  54.4s
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  55.1s
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  55.9s
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time=  55.6s
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.3min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.3min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.3min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.5min
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.5min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.986 total time=  49.6s
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.990 total time=  49.3s
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time=  49.1s
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time=  49.7s
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  50.2s
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.986 total time=  59.3s
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.990 total time=  58.6s
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.990 total time=  59.0s
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.989 total time=  59.3s
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time=  59.6s
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.987 total time= 1.2min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.990 total time= 1.1min
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.990 total time= 1.2min
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time= 1.2min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time= 1.2min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.990 total time= 1.3min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.987 total time= 1.3min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.990 total time= 1.3min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.3min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.3min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time=  52.5s
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time=  53.7s
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time=  53.5s
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time=  53.8s
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time=  53.6s
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.2min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.2min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.2min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.2min
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.2min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time=  52.6s
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time=  53.3s
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time=  53.7s
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time=  53.6s
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time=  53.4s
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.1min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.1min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.2min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.2min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.2min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.2min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.2min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.4min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.4min

# %%
score_calc("Random Forest With Cluster NAN 60 PCA 95%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_Cluster_60_95", True)
# Out:
# Random Forest With Cluster NAN 60 PCA 95%
# Confusion Matrix
# [[9662  132]
#  [  18  163]]
# Validation F3 Score: 0.8471933471933472
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9794
#            1       0.55      0.90      0.68       181
#
#     accuracy                           0.98      9975
#    macro avg       0.78      0.94      0.84      9975
# weighted avg       0.99      0.98      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=20, max_features='sqrt',
#                        n_estimators=150, random_state=42)

# %%
X, y = over_sampling(X_train_20_99, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_20_99)
test_pred = gridSearch.predict(X_test_20_99)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.973 total time=  54.8s
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.974 total time=  54.8s
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.971 total time=  54.8s
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.971 total time=  54.9s
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.974 total time=  54.9s
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.972 total time=  59.5s
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.971 total time=  59.6s
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.973 total time=  59.6s
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.974 total time=  59.7s
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.974 total time=  59.7s
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.971 total time= 1.1min
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.973 total time= 1.1min
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.974 total time= 1.1min
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.974 total time= 1.1min
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.972 total time= 1.1min
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.971 total time= 1.3min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.973 total time= 1.3min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.974 total time= 1.3min
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.974 total time= 1.3min
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.972 total time= 1.3min
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.2min
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.2min
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.997 total time= 1.2min
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.2min
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.997 total time= 1.2min
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.4min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.4min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.997 total time= 1.4min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.997 total time= 1.4min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.4min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.997 total time= 1.6min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.997 total time= 1.6min
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.997 total time= 1.6min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.997 total time= 1.9min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.997 total time= 1.9min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.997 total time= 1.9min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.997 total time= 1.9min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.9min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.2min
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.997 total time= 1.2min
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.2min
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.2min
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.2min
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.4min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.997 total time= 1.4min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.4min
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.4min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.4min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.7min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.997 total time= 1.7min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.7min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.7min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.7min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.9min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.997 total time= 1.9min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.9min
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.9min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.977 total time=  59.5s
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.976 total time= 1.0min
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.976 total time=  60.0s
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.979 total time=  59.4s
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.977 total time= 1.0min
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.976 total time= 1.2min
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.976 total time= 1.2min
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.976 total time= 1.2min
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.978 total time= 1.2min
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.976 total time= 1.2min
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.976 total time= 1.4min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.976 total time= 1.4min
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.976 total time= 1.4min
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.978 total time= 1.4min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.976 total time= 1.4min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.976 total time= 1.6min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.977 total time= 1.6min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.976 total time= 1.6min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.978 total time= 1.6min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.975 total time= 1.6min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.1min
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.1min
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.1min
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.3min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.3min
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.3min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.3min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.8min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.8min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.8min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.1min
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.1min
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.1min
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.3min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.3min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.3min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.6min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.8min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.8min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 1.8min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min

# %%
score_calc("Random Forest NAN 20 PCA 99%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_20_99", True)
# Out:
# Random Forest NAN 20 PCA 99%
# Confusion Matrix
# [[9654  141]
#  [  11  169]]
# Validation F3 Score: 0.8756476683937823
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9795
#            1       0.55      0.94      0.69       180
#
#     accuracy                           0.98      9975
#    macro avg       0.77      0.96      0.84      9975
# weighted avg       0.99      0.98      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=30, max_features='sqrt',
#                        n_estimators=175, random_state=42)

# %%
X, y = over_sampling(X_train_20_99, y_train)
y_train_ravel = y.values.ravel()

params = [{"n_components": [2],
          "covariance_type": ["spherical", "tied", "diag", "full"]}]
model = GaussianMixture(random_state=42)
CgridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
CgridSearch.fit(X, y_train_ravel)
y_pred_val = CgridSearch.predict(X_val_20_99)
test_pred = CgridSearch.predict(X_test_20_99)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 2/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 3/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 5/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.959 total time=   1.3s
# [CV 3/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.962 total time=   1.4s
# [CV 5/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.960 total time=   1.3s
# [CV 3/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 2/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 1/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 1/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.962 total time=   1.6s
# [CV 2/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.981 total time=   1.7s
# [CV 4/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 5/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 3/5; 2/4] END covariance_type=tied, n_components=2;, score=0.457 total time=   3.8s
# [CV 1/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 4/5; 2/4] END covariance_type=tied, n_components=2;, score=0.455 total time=   4.1s
# [CV 2/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 5/5; 2/4] END covariance_type=tied, n_components=2;, score=0.455 total time=   4.2s
# [CV 3/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 1/5; 2/4] END covariance_type=tied, n_components=2;, score=0.438 total time=   5.3s
# [CV 4/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 1/5; 3/4] END covariance_type=diag, n_components=2;, score=0.967 total time=   2.5s
# [CV 5/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 3/5; 3/4] END covariance_type=diag, n_components=2;, score=0.966 total time=   2.0s
# [CV 1/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 2/5; 3/4] END covariance_type=diag, n_components=2;, score=0.981 total time=   2.8s
# [CV 2/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 4/5; 3/4] END covariance_type=diag, n_components=2;, score=0.964 total time=   1.9s
# [CV 3/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 5/5; 3/4] END covariance_type=diag, n_components=2;, score=0.966 total time=   1.9s
# [CV 4/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 2/5; 2/4] END covariance_type=tied, n_components=2;, score=0.459 total time=   8.7s
# [CV 5/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 2/5; 4/4] END covariance_type=full, n_components=2;, score=0.813 total time=   9.9s
# [CV 1/5; 4/4] END covariance_type=full, n_components=2;, score=0.805 total time=  13.3s
# [CV 3/5; 4/4] END covariance_type=full, n_components=2;, score=0.838 total time=  13.2s
# [CV 5/5; 4/4] END covariance_type=full, n_components=2;, score=0.981 total time=  18.3s
# [CV 4/5; 4/4] END covariance_type=full, n_components=2;, score=0.981 total time=  20.2s

# %%
score_calc("GMM NAN 20 PCA 99%", y_val,  y_pred_val)
# Out:
# Random Forest NAN 20 PCA 99%
# Confusion Matrix
# [[8575 1220]
#  [   3  177]]
# Validation F3 Score: 0.5866755054690088
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.93      9795
#            1       0.13      0.98      0.22       180
#
#     accuracy                           0.88      9975
#    macro avg       0.56      0.93      0.58      9975
# weighted avg       0.98      0.88      0.92      9975

# %%
train_pred = CgridSearch.predict(X_train_20_99)
pred = np.reshape(train_pred, (train_pred.shape[0], 1))
X_train_20_99_cluster = np.append(X_train_20_99, pred, axis=1)

y_pred_val = CgridSearch.predict(X_val_20_99)
pred = np.reshape(y_pred_val, (y_pred_val.shape[0], 1))
X_val_20_99_cluster = np.append(X_val_20_99, pred, axis=1)

test_pred = CgridSearch.predict(X_test_20_99)
pred = np.reshape(test_pred, (test_pred.shape[0], 1))
X_test_20_99_cluster = np.append(X_test_20_99, pred, axis=1)

print(X_train_20_99_cluster[0].size)
print(X_val_20_99_cluster[0].size)
print(X_test_20_99_cluster[0].size)
# Out:
# 98
# 98
# 98

# %%
X, y = over_sampling(X_train_20_99_cluster, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_20_99_cluster)
test_pred = gridSearch.predict(X_test_20_99_cluster)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.983 total time=  50.3s
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.985 total time=  50.4s
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.981 total time=  50.4s
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.983 total time=  50.4s
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.979 total time=  50.8s
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.985 total time=  58.2s
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.982 total time=  58.2s
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.981 total time=  58.4s
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.980 total time=  58.6s
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.983 total time=  58.5s
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.984 total time= 1.1min
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.981 total time= 1.2min
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.983 total time= 1.1min
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.980 total time= 1.2min
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.983 total time= 1.2min
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.984 total time= 1.3min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.982 total time= 1.3min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.983 total time= 1.3min
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.982 total time= 1.3min
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.983 total time= 1.3min
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.0min
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.0min
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.0min
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.0min
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.0min
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.2min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.6min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  55.3s
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.987 total time=  55.0s
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.987 total time=  54.9s
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time=  54.9s
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.991 total time=  55.1s
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time= 1.1min
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.986 total time= 1.1min
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.987 total time= 1.1min
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.989 total time= 1.1min
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.991 total time= 1.1min
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time= 1.3min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.986 total time= 1.3min
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.987 total time= 1.3min
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time= 1.3min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.991 total time= 1.3min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.5min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.986 total time= 1.5min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.987 total time= 1.5min
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.5min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.991 total time= 1.5min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.0min
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.0min
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.0min
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.0min
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.0min
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.2min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.2min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.2min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.4min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.4min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.4min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.6min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.6min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.6min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.6min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.6min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.0min
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.0min
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.0min
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.0min
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.0min
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.2min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.2min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.2min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.2min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.4min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.4min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.4min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.4min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.4min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.6min
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.6min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.6min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.6min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.6min

# %%
score_calc("Random Forest With Cluster NAN 20 PCA 99%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_Cluster_20_99", True)
# Out:
# Random Forest With Cluster NAN 20 PCA 99%
# Confusion Matrix
# [[9649  146]
#  [  16  164]]
# Validation F3 Score: 0.8497409326424871
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9795
#            1       0.53      0.91      0.67       180
#
#     accuracy                           0.98      9975
#    macro avg       0.76      0.95      0.83      9975
# weighted avg       0.99      0.98      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=30, max_features='sqrt',
#                        n_estimators=175, random_state=42)

# %%
X, y = over_sampling(X_train_30_99, y_train)
y_train_ravel = y.values.ravel()

params = [{"n_components": [2],
          "covariance_type": ["spherical", "tied", "diag", "full"]}]
model = GaussianMixture(random_state=42)
CgridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
CgridSearch.fit(X, y_train_ravel)
y_pred_val = CgridSearch.predict(X_train_30_99)
test_pred = CgridSearch.predict(X_test_30_99)

train_pred = CgridSearch.predict(X_train_30_99)
pred = np.reshape(train_pred, (train_pred.shape[0], 1))
X_train_30_99_cluster = np.append(X_train_30_99, pred, axis=1)

y_pred_val = CgridSearch.predict(X_val_30_99)
pred = np.reshape(y_pred_val, (y_pred_val.shape[0], 1))
X_val_30_99_cluster = np.append(X_val_30_99, pred, axis=1)

test_pred = CgridSearch.predict(X_test_30_99)
pred = np.reshape(test_pred, (test_pred.shape[0], 1))
X_test_30_99_cluster = np.append(X_test_30_99, pred, axis=1)

print(X_train_30_99_cluster[0].size)
print(X_val_30_99_cluster[0].size)
print(X_test_30_99_cluster[0].size)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 2/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 3/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 5/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.960 total time=   1.4s
# [CV 5/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.955 total time=   1.3s
# [CV 1/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 2/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 3/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.959 total time=   1.5s
# [CV 3/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 2/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.977 total time=   1.7s
# [CV 1/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.966 total time=   1.8s
# [CV 4/5; 2/4] START covariance_type=tied, n_components=2........................[CV 5/5; 2/4] START covariance_type=tied, n_components=2........................
#
# [CV 5/5; 2/4] END covariance_type=tied, n_components=2;, score=0.491 total time=   4.0s
# [CV 1/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 4/5; 2/4] END covariance_type=tied, n_components=2;, score=0.471 total time=   4.4s
# [CV 2/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 1/5; 2/4] END covariance_type=tied, n_components=2;, score=0.394 total time=   5.9s
# [CV 3/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 1/5; 3/4] END covariance_type=diag, n_components=2;, score=0.975 total time=   2.7s
# [CV 4/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 3/5; 2/4] END covariance_type=tied, n_components=2;, score=0.392 total time=   7.1s
# [CV 5/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 2/5; 3/4] END covariance_type=diag, n_components=2;, score=0.991 total time=   2.6s
# [CV 1/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 3/5; 3/4] END covariance_type=diag, n_components=2;, score=0.970 total time=   2.0s
# [CV 2/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 4/5; 3/4] END covariance_type=diag, n_components=2;, score=0.972 total time=   1.9s
# [CV 3/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 5/5; 3/4] END covariance_type=diag, n_components=2;, score=0.968 total time=   1.8s
# [CV 4/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 2/5; 2/4] END covariance_type=tied, n_components=2;, score=0.482 total time=   9.4s
# [CV 5/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 3/5; 4/4] END covariance_type=full, n_components=2;, score=0.861 total time=  10.0s
# [CV 1/5; 4/4] END covariance_type=full, n_components=2;, score=0.837 total time=  12.1s
# [CV 2/5; 4/4] END covariance_type=full, n_components=2;, score=0.872 total time=  11.8s
# [CV 5/5; 4/4] END covariance_type=full, n_components=2;, score=0.961 total time=  12.2s
# [CV 4/5; 4/4] END covariance_type=full, n_components=2;, score=0.968 total time=  14.8s
# 107
# 107
# 107

# %%
X, y = over_sampling(X_train_30_99_cluster, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_30_99_cluster)
test_pred = gridSearch.predict(X_test_30_99_cluster)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.992 total time=  54.1s
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.991 total time=  54.1s
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  54.1s
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.990 total time=  54.1s
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time=  54.5s
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.991 total time= 1.1min
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.990 total time= 1.1min
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.990 total time= 1.1min
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.989 total time= 1.1min
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time= 1.1min
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.991 total time= 1.3min
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.990 total time= 1.3min
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time= 1.3min
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time= 1.3min
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time= 1.3min
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.991 total time= 1.5min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.991 total time= 1.5min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.5min
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.990 total time= 1.5min
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.5min
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.3min
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.3min
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.7min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.7min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.5min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.5min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.7min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.9min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 2.0min
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.994 total time= 1.0min
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.992 total time= 1.0min
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.994 total time= 1.0min
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.991 total time= 1.0min
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time= 1.0min
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.994 total time= 1.2min
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.993 total time= 1.2min
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.992 total time= 1.2min
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.992 total time= 1.2min
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.989 total time= 1.2min
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.993 total time= 1.5min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.993 total time= 1.4min
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.992 total time= 1.5min
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.992 total time= 1.4min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time= 1.5min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.994 total time= 1.6min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.993 total time= 1.6min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.993 total time= 1.6min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.992 total time= 1.7min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.990 total time= 1.7min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.3min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.3min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.3min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min

# %%
score_calc("Random Forest With Cluster NAN 30 PCA 99%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_Cluster_30_99", True)
# Out:
# Random Forest With Cluster NAN 30 PCA 99%
# Confusion Matrix
# [[9672  122]
#  [  20  161]]
# Validation F3 Score: 0.8420502092050208
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9794
#            1       0.57      0.89      0.69       181
#
#     accuracy                           0.99      9975
#    macro avg       0.78      0.94      0.84      9975
# weighted avg       0.99      0.99      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=30, max_features='sqrt',
#                        n_estimators=200, random_state=42)

# %%
X, y = over_sampling(X_train_40_99, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_40_99)
test_pred = gridSearch.predict(X_test_40_99)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125[CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
#
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.973 total time=  58.9s
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.974 total time=  58.8s
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.972 total time=  58.9s
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.973 total time=  59.0s
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.973 total time=  59.0s
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.973 total time= 1.1min
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.973 total time= 1.1min
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.972 total time= 1.1min
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.973 total time= 1.1min
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.973 total time= 1.1min
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.973 total time= 1.3min
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.974 total time= 1.3min
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.972 total time= 1.3min
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200[CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
#
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.973 total time= 1.3min
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.973 total time= 1.3min
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.973 total time= 1.4min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.972 total time= 1.4min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.973 total time= 1.4min
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.973 total time= 1.5min
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.973 total time= 1.5min
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.3min
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.3min
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.3min
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.5min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.5min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.5min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.8min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.8min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.8min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.0min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.0min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.0min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.3min
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.3min
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.6min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.6min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.8min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.1min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.976 total time= 1.1min
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.976 total time= 1.1min
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.977 total time= 1.1min
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.977 total time= 1.1min
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.977 total time= 1.1min
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.977 total time= 1.3min
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.976 total time= 1.3min
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.977 total time= 1.3min
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.978 total time= 1.3min
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.977 total time= 1.3min
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.977 total time= 1.5min
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.977 total time= 1.5min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.978 total time= 1.5min
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.978 total time= 1.5min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.978 total time= 1.5min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.976 total time= 1.8min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.977 total time= 1.8min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.978 total time= 1.8min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.978 total time= 1.8min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.978 total time= 1.8min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.5min
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.5min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.7min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.7min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.0min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.0min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.2min
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.5min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.5min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.5min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.8min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.8min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.8min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.0min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.0min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min

# %%
score_calc("Random Forest NAN 40 PCA 99%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_40_99", True)
# Out:
# Random Forest NAN 40 PCA 99%
# Confusion Matrix
# [[9665  130]
#  [  12  168]]
# Validation F3 Score: 0.875912408759124
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9795
#            1       0.56      0.93      0.70       180
#
#     accuracy                           0.99      9975
#    macro avg       0.78      0.96      0.85      9975
# weighted avg       0.99      0.99      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=20, max_features='sqrt',
#                        n_estimators=125, random_state=42)

# %%
X, y = over_sampling(X_train_40_99, y_train)
y_train_ravel = y.values.ravel()

params = [{"n_components": [2],
          "covariance_type": ["spherical", "tied", "diag", "full"]}]
model = GaussianMixture(random_state=42)
CgridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
CgridSearch.fit(X, y_train_ravel)
y_pred_val = CgridSearch.predict(X_train_40_99)
test_pred = CgridSearch.predict(X_test_40_99)

train_pred = CgridSearch.predict(X_train_40_99)
pred = np.reshape(train_pred, (train_pred.shape[0], 1))
X_train_40_99_cluster = np.append(X_train_40_99, pred, axis=1)

y_pred_val = CgridSearch.predict(X_val_40_99)
pred = np.reshape(y_pred_val, (y_pred_val.shape[0], 1))
X_val_40_99_cluster = np.append(X_val_40_99, pred, axis=1)

test_pred = CgridSearch.predict(X_test_40_99)
pred = np.reshape(test_pred, (test_pred.shape[0], 1))
X_test_40_99_cluster = np.append(X_test_40_99, pred, axis=1)

print(X_train_40_99_cluster[0].size)
print(X_val_40_99_cluster[0].size)
print(X_test_40_99_cluster[0].size)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 2/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 3/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 5/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 5/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.948 total time=   1.3s
# [CV 4/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.946 total time=   1.4s
# [CV 1/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 2/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 3/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.947 total time=   1.6s
# [CV 3/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 1/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.966 total time=   1.8s
# [CV 4/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 2/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.947 total time=   1.9s
# [CV 5/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 2/5; 2/4] END covariance_type=tied, n_components=2;, score=0.507 total time=   3.8s
# [CV 1/5; 2/4] END covariance_type=tied, n_components=2;, score=0.529 total time=   3.9s
# [CV 2/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 1/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 3/5; 2/4] END covariance_type=tied, n_components=2;, score=0.495 total time=   3.8s
# [CV 3/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 3/5; 3/4] END covariance_type=diag, n_components=2;, score=0.965 total time=   2.1s
# [CV 4/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 1/5; 3/4] END covariance_type=diag, n_components=2;, score=0.990 total time=   2.5s
# [CV 2/5; 3/4] END covariance_type=diag, n_components=2;, score=0.962 total time=   2.5s
# [CV 5/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 1/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 4/5; 2/4] END covariance_type=tied, n_components=2;, score=0.550 total time=   7.0s
# [CV 2/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 5/5; 2/4] END covariance_type=tied, n_components=2;, score=0.557 total time=   7.0s
# [CV 3/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 4/5; 3/4] END covariance_type=diag, n_components=2;, score=0.966 total time=   1.7s
# [CV 4/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 5/5; 3/4] END covariance_type=diag, n_components=2;, score=0.965 total time=   1.6s
# [CV 5/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 1/5; 4/4] END covariance_type=full, n_components=2;, score=0.846 total time=  15.3s
# [CV 3/5; 4/4] END covariance_type=full, n_components=2;, score=0.870 total time=  15.8s
# [CV 2/5; 4/4] END covariance_type=full, n_components=2;, score=0.837 total time=  16.9s
# [CV 5/5; 4/4] END covariance_type=full, n_components=2;, score=0.988 total time=  18.2s
# [CV 4/5; 4/4] END covariance_type=full, n_components=2;, score=0.987 total time=  21.1s
# 108
# 108
# 108

# %%
X, y = over_sampling(X_train_40_99_cluster, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_40_99_cluster)
test_pred = gridSearch.predict(X_test_40_99_cluster)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.986 total time=  57.5s
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.986 total time=  57.6s
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.985 total time=  57.7s
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.980 total time=  57.8s
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.986 total time=  58.0s
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.985 total time= 1.2min
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.981 total time= 1.2min
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.985 total time= 1.2min
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.985 total time= 1.2min
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.985 total time= 1.2min
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.985 total time= 1.3min
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.980 total time= 1.3min
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.984 total time= 1.3min
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.985 total time= 1.3min
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.985 total time= 1.3min
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.985 total time= 1.4min
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.980 total time= 1.4min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.986 total time= 1.4min
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.985 total time= 1.4min
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.985 total time= 1.4min
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.3min
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.3min
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.3min
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.5min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.6min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.6min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.6min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.6min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 2.4min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.5min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 2.5min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.5min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.5min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 2.5min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.6min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.6min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 2.5min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.6min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.5min
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.5min
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.5min
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.5min
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.9min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.9min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.9min
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.9min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.9min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 2.1min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 2.1min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.1min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 2.1min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.1min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 2.0min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 2.0min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.1min
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 2.0min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time= 1.2min
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.991 total time= 1.2min
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.986 total time= 1.2min
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time= 1.2min
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time= 1.2min
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time= 1.2min
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.991 total time= 1.2min
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.986 total time= 1.2min
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.990 total time= 1.2min
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time= 1.2min
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time= 1.4min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.990 total time= 1.5min
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.986 total time= 1.5min
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time= 1.4min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.987 total time= 1.5min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.6min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.991 total time= 1.7min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.986 total time= 1.7min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.7min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.7min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.3min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.3min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.3min
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.5min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.5min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.7min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.7min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.3min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.3min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.3min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.5min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.5min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.5min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.7min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.7min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.7min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min

# %%
score_calc("Random Forest With Cluster NAN 40 PCA 99%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_Cluster_40_99", True)
# Out:
# Random Forest With Cluster NAN 40 PCA 99%
# Confusion Matrix
# [[9654  140]
#  [  27  154]]
# Validation F3 Score: 0.8008320332813313
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9794
#            1       0.52      0.85      0.65       181
#
#     accuracy                           0.98      9975
#    macro avg       0.76      0.92      0.82      9975
# weighted avg       0.99      0.98      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=20, max_features='sqrt',
#                        n_estimators=125, random_state=42)

# %%
X, y = over_sampling(X_train_60_99, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_60_99)
test_pred = gridSearch.predict(X_test_60_99)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.976 total time= 1.2min
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.975 total time= 1.2min
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.976 total time= 1.2min
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.974 total time= 1.2min
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.973 total time= 1.3min
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.974 total time= 1.5min
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.976 total time= 1.5min
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.975 total time= 1.5min
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.976 total time= 1.5min
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.973 total time= 1.5min
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.974 total time= 1.9min
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.975 total time= 1.9min
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.976 total time= 1.9min
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.974 total time= 1.9min
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.973 total time= 1.9min
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.974 total time= 1.7min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.975 total time= 1.7min
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.976 total time= 1.7min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.975 total time= 1.7min
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.973 total time= 1.7min
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.6min
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.6min
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.9min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.9min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.9min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.9min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.9min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 2.2min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.3min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 2.2min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 2.3min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.3min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.5min
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.5min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.5min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.5min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.5min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.6min
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 2.1min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 2.1min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 2.1min
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 2.1min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 2.1min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.4min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.4min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 2.4min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.4min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.4min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.7min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.7min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.7min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.7min
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.7min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.978 total time= 1.4min
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.979 total time= 1.4min
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.979 total time= 1.4min
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.979 total time= 1.4min
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.976 total time= 1.4min
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.978 total time= 1.8min
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.979 total time= 1.8min
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.979 total time= 1.8min
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.979 total time= 1.8min
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.977 total time= 1.8min
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.978 total time= 2.0min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.978 total time= 2.0min
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.978 total time= 2.0min
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.978 total time= 2.0min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.977 total time= 2.0min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.979 total time= 2.3min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.978 total time= 2.3min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.978 total time= 2.3min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.978 total time= 2.3min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.977 total time= 2.3min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.6min
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.9min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 2.0min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.9min
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.998 total time= 1.9min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.9min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.2min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.2min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.2min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 2.2min
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.998 total time= 2.2min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.6min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.6min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.6min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.6min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.6min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.5min
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.998 total time= 1.5min
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.5min
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.6min
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 2.0min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 2.0min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 2.0min
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 2.0min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.998 total time= 2.0min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.9min
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.9min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.9min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.9min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.998 total time= 1.9min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.9min
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 2.0min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.998 total time= 2.0min

# %%
score_calc("Random Forest NAN 60 PCA 99%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_60_99", True)
# Out:
# Random Forest NAN 60 PCA 99%
# Confusion Matrix
# [[9660  135]
#  [  13  167]]
# Validation F3 Score: 0.8688865764828305
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9795
#            1       0.55      0.93      0.69       180
#
#     accuracy                           0.99      9975
#    macro avg       0.78      0.96      0.84      9975
# weighted avg       0.99      0.99      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=20, max_features='sqrt',
#                        n_estimators=200, random_state=42)

# %%
X, y = over_sampling(X_train_60_99, y_train)
y_train_ravel = y.values.ravel()

params = [{"n_components": [2],
          "covariance_type": ["spherical", "tied", "diag", "full"]}]
model = GaussianMixture(random_state=42)
CgridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
CgridSearch.fit(X, y_train_ravel)
y_pred_val = CgridSearch.predict(X_val_60_99)
test_pred = CgridSearch.predict(X_test_60_99)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 2/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 3/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 5/5; 1/4] START covariance_type=spherical, n_components=2...................
# [CV 4/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.063 total time=   1.3s
# [CV 5/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.940 total time=   1.3s
# [CV 1/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 2/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 2/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.955 total time=   1.6s
# [CV 3/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.933 total time=   1.6s
# [CV 1/5; 1/4] END covariance_type=spherical, n_components=2;, score=0.936 total time=   1.7s
# [CV 3/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 5/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 4/5; 2/4] START covariance_type=tied, n_components=2........................
# [CV 2/5; 2/4] END covariance_type=tied, n_components=2;, score=0.513 total time=   5.8s
# [CV 1/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 4/5; 2/4] END covariance_type=tied, n_components=2;, score=0.532 total time=   6.1s
# [CV 2/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 1/5; 2/4] END covariance_type=tied, n_components=2;, score=0.459 total time=   6.6s
# [CV 3/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 3/5; 2/4] END covariance_type=tied, n_components=2;, score=0.459 total time=   6.8s
# [CV 4/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 5/5; 2/4] END covariance_type=tied, n_components=2;, score=0.455 total time=   7.5s
# [CV 5/5; 3/4] START covariance_type=diag, n_components=2........................
# [CV 4/5; 3/4] END covariance_type=diag, n_components=2;, score=0.030 total time=   1.9s
# [CV 1/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 3/5; 3/4] END covariance_type=diag, n_components=2;, score=0.964 total time=   2.6s
# [CV 2/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 1/5; 3/4] END covariance_type=diag, n_components=2;, score=0.982 total time=   3.6s
# [CV 3/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 5/5; 3/4] END covariance_type=diag, n_components=2;, score=0.968 total time=   1.9s
# [CV 4/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 2/5; 3/4] END covariance_type=diag, n_components=2;, score=0.980 total time=   3.4s
# [CV 5/5; 4/4] START covariance_type=full, n_components=2........................
# [CV 2/5; 4/4] END covariance_type=full, n_components=2;, score=0.864 total time=  12.6s
# [CV 3/5; 4/4] END covariance_type=full, n_components=2;, score=0.862 total time=  13.2s
# [CV 1/5; 4/4] END covariance_type=full, n_components=2;, score=0.891 total time=  18.7s
# [CV 5/5; 4/4] END covariance_type=full, n_components=2;, score=0.971 total time=  19.3s
# [CV 4/5; 4/4] END covariance_type=full, n_components=2;, score=0.030 total time=  20.5s

# %%
score_calc("GMM NAN 60 PCA 99%", y_val,  y_pred_val)
# Out:
# GMM NAN 60 PCA 99%
# Confusion Matrix
# [[1200 8594]
#  [ 179    2]]
# Validation F3 Score: 0.0019559902200489
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.87      0.12      0.21      9794
#            1       0.00      0.01      0.00       181
#
#     accuracy                           0.12      9975
#    macro avg       0.44      0.07      0.11      9975
# weighted avg       0.85      0.12      0.21      9975

# %%
train_pred = CgridSearch.predict(X_train_60_99)
pred = np.reshape(train_pred, (train_pred.shape[0], 1))
X_train_60_99_cluster = np.append(X_train_60_99, pred, axis=1)

y_pred_val = CgridSearch.predict(X_val_60_99)
pred = np.reshape(y_pred_val, (y_pred_val.shape[0], 1))
X_val_60_99_cluster = np.append(X_val_60_99, pred, axis=1)

test_pred = CgridSearch.predict(X_test_60_99)
pred = np.reshape(test_pred, (test_pred.shape[0], 1))
X_test_60_99_cluster = np.append(X_test_60_99, pred, axis=1)

print(X_train_60_99_cluster[0].size)
print(X_val_60_99_cluster[0].size)
print(X_test_60_99_cluster[0].size)
# Out:
# 109
# 109
# 109

# %%
X, y = over_sampling(X_train_60_99_cluster, y_train)
y_train_ravel = y.values.ravel()

params = [{'criterion': ['gini', 'entropy'], 
           'max_features': ['sqrt'], 
           'n_estimators': range(125,201,25),
           'max_depth': [10,20,30]}]
model = RandomForestClassifier(random_state=42)
gridSearch = GridSearchCV(model, params, cv=5, scoring='recall', verbose=10, n_jobs=5) 
gridSearch.fit(X, y_train_ravel)
y_pred_val = gridSearch.predict(X_val_60_99_cluster)
test_pred = gridSearch.predict(X_test_60_99_cluster)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 1/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 1/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.986 total time=  53.9s
# [CV 1/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.985 total time=  53.9s
# [CV 2/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.986 total time=  54.1s
# [CV 3/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time=  54.2s
# [CV 4/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 1/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.986 total time=  54.2s
# [CV 5/5; 2/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.986 total time= 1.0min
# [CV 1/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time= 1.0min
# [CV 2/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 1/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.986 total time= 1.0min
# [CV 3/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.986 total time= 1.0min
# [CV 4/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 2/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.986 total time= 1.0min
# [CV 5/5; 3/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.986 total time= 1.2min
# [CV 1/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.986 total time= 1.2min
# [CV 2/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time= 1.2min
# [CV 3/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.986 total time= 1.2min
# [CV 4/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 3/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.986 total time= 1.2min
# [CV 5/5; 4/24] START criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.986 total time= 1.4min
# [CV 1/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.989 total time= 1.4min
# [CV 2/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.986 total time= 1.4min
# [CV 3/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.986 total time= 1.4min
# [CV 4/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 4/24] END criterion=gini, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.985 total time= 1.4min
# [CV 5/5; 5/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 1/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 2/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 3/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 4/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 5/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 5/5; 6/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 1/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 2/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 3/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 4/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 6/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 5/5; 7/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 1/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 2/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 3/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 4/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 7/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 5/5; 8/24] START criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 1/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 2/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.9min
# [CV 3/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.9min
# [CV 4/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 8/24] END criterion=gini, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 5/5; 9/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.2min
# [CV 1/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 2/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 3/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 4/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 9/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 5/5; 10/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 1/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 2/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 3/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.4min
# [CV 4/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 10/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 5/5; 11/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 1/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 2/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 3/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 4/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 11/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.7min
# [CV 5/5; 12/24] START criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 1/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 2/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.9min
# [CV 2/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 3/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.9min
# [CV 3/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 4/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 4/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 5/5; 12/24] END criterion=gini, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.9min
# [CV 5/5; 13/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125
# [CV 1/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.987 total time= 1.0min
# [CV 1/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 2/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.989 total time= 1.0min
# [CV 2/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 3/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.990 total time= 1.0min
# [CV 3/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 4/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.988 total time= 1.0min
# [CV 4/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 5/5; 13/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=125;, score=0.987 total time= 1.0min
# [CV 5/5; 14/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150
# [CV 1/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.987 total time= 1.2min
# [CV 1/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time= 1.2min
# [CV 2/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 3/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.990 total time= 1.2min
# [CV 3/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 4/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.988 total time= 1.2min
# [CV 4/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 5/5; 14/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=150;, score=0.987 total time= 1.2min
# [CV 5/5; 15/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175
# [CV 2/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.989 total time= 1.4min
# [CV 1/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 1/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.987 total time= 1.4min
# [CV 2/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 3/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.990 total time= 1.4min
# [CV 3/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 4/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.988 total time= 1.4min
# [CV 4/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 5/5; 15/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=175;, score=0.987 total time= 1.4min
# [CV 5/5; 16/24] START criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200
# [CV 2/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.6min
# [CV 1/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.987 total time= 1.6min
# [CV 2/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 3/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.990 total time= 1.6min
# [CV 3/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 4/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.988 total time= 1.6min
# [CV 4/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 5/5; 16/24] END criterion=entropy, max_depth=10, max_features=sqrt, n_estimators=200;, score=0.986 total time= 1.7min
# [CV 5/5; 17/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125
# [CV 1/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 1/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 2/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 2/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 3/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 3/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 4/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 4/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 5/5; 17/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 5/5; 18/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150
# [CV 1/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 1/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 3/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.3min
# [CV 2/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 2/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 3/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 4/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 4/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 5/5; 18/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 5/5; 19/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175
# [CV 1/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 1/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 2/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 3/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 4/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 19/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 5/5; 20/24] START criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 1/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 3/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 2/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 2/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 3/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 4/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 4/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 5/5; 20/24] END criterion=entropy, max_depth=20, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.9min
# [CV 5/5; 21/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125
# [CV 1/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=0.999 total time= 1.1min
# [CV 1/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 3/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 2/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 2/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 3/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 4/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.1min
# [CV 4/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 5/5; 21/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=125;, score=1.000 total time= 1.2min
# [CV 5/5; 22/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150
# [CV 1/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=0.999 total time= 1.3min
# [CV 1/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 3/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.3min
# [CV 2/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 2/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 3/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 4/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 4/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 5/5; 22/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=150;, score=1.000 total time= 1.4min
# [CV 5/5; 23/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175
# [CV 1/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=0.999 total time= 1.6min
# [CV 1/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 2/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 3/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 4/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=175;, score=1.000 total time= 1.6min
# [CV 5/5; 24/24] START criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.999 total time= 1.8min
# [CV 2/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 3/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 4/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min
# [CV 5/5; 24/24] END criterion=entropy, max_depth=30, max_features=sqrt, n_estimators=200;, score=1.000 total time= 1.8min

# %%
score_calc("Random Forest With Cluster NAN 60 PCA 99%", y_val,  y_pred_val)
save_model(gridSearch, test_pred, "Random_Forest_Cluster_60_99", True)
# Out:
# Random Forest With Cluster NAN 60 PCA 99%
# Confusion Matrix
# [[9664  130]
#  [  21  160]]
# Validation F3 Score: 0.8337675872850443
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      9794
#            1       0.55      0.88      0.68       181
#
#     accuracy                           0.98      9975
#    macro avg       0.77      0.94      0.84      9975
# weighted avg       0.99      0.98      0.99      9975
#
# Best Estimator: RandomForestClassifier(criterion='entropy', max_depth=20, max_features='sqrt',
#                        n_estimators=175, random_state=42)
